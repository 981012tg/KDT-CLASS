# %% [markdown]
# # 01 제1유형
#
# 기출문제 6회 제1유형 연습입니다.
# 각 문제는 **서로 다른 CSV**를 사용합니다.
#
# **데이터 URL (공통 경로)**
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/
# ```

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 문제 ① 구급대 평균 이동시간
#
# 주어진 데이터를 이용하여 **이동시간**(출동시간과 도착시간의 차이)이
# 평균적으로 **가장 오래 걸린 구급대**의 이동시간을 구하시오.
#
# - 분 단위로 환산
# - 반올림하여 **정수**로 출력
#
# **데이터**: `data_6_1_1.csv`
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/data_6_1_1.csv
# ```
#
# > 출력: 평균 이동시간(분, 정수)

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/YoungjinBD/dataset/main/data_6_1_1.csv")

df1["도착시간"] = pd.to_datetime(df1["도착시간"])
df1["출동시간"] = pd.to_datetime(df1["출동시간"])

df1["이동시간"] = df1["도착시간"] - df1["출동시간"]
df1["이동시간"] = (df1["이동시간"].dt.total_seconds() / 60).astype(int)
df1["이동시간"]

# df1["이동시간"].sort_values(ascending=False)

idx=df1["이동시간"].idxmax()
df1["이동시간"].loc[idx]

grouped = df1.groupby("구급대")
grouped["이동시간"].agg("mean").sort_values(ascending=False)
# Out:
# 구급대
# 구급대7     82.777778
# 구급대9     80.133333
# 구급대5     60.900000
# 구급대2     59.714286
# 구급대1     54.428571
# 구급대4     48.600000
# 구급대3     43.111111
# 구급대8     42.375000
# 구급대10    41.900000
# 구급대6     41.250000
# Name: 이동시간, dtype: float64

# %% [markdown]
# ## 문제 ② 교수 1인당 학생 수가 가장 많은 대학
#
# 주어진 데이터를 이용하여 **교수 1인당 맡고 있는 학생 수**가 가장 많은 대학교를 찾고,
# 그 대학교의 **전체 교수 수**를 구하시오. (**정수**로 출력)
#
# **데이터**: `data_6_1_2.csv`
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/data_6_1_2.csv
# ```
#
# > 출력: 해당 대학교의 전체 교수 수(정수)

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/YoungjinBD/dataset/main/data_6_1_2.csv")
# df2.head()

df2["학생"] = df2.iloc[:, 2:].sum(axis=1)
df2.head()
df2["학생/교수"] = df2["학생"] / df2["교수"]
# df2.head()

df2["학생/교수"].sort_values(ascending=False)

df2.iloc[45]
# Out:
# 대학교명          대학교46
# 교수               22
# 경영학과            163
# 경제학과            189
# 컴퓨터공학과          192
# 산업공학과           121
# 국문학과             99
# 영문학과            183
# 학생              947
# 학생/교수     43.045455
# Name: 45, dtype: object

# %% [markdown]
# ## 문제 ③ 연도별 총 범죄 건수 월평균
#
# 주어진 데이터를 이용하여 **연도별 총 범죄 건수의 월평균** 값을 구하고,
# 그 값이 **가장 큰 연도**의 총 범죄 건수 월평균 값을 집계하시오.
#
# - 반올림하여 **정수**로 출력
#
# **데이터**: `data_6_1_3.csv`
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/data_6_1_3.csv
# ```
#
# > 출력: 월평균 최댓값(정수)

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/YoungjinBD/dataset/main/data_6_1_3.csv")
df3.head()

df3["총범죄건수"] = df3.iloc[:, 1:7].sum(axis=1)
df3.head()
# df3.info()

df3["연도"] = df3["날짜"].str[0:4]
# df3["연도"] = pd.to_datetime(df3["날짜"], format="%Y년 %m월").dt.year
df3.head()

grouped = df3.groupby("연도")
grouped["총범죄건수"].agg("mean").sort_values(ascending=False)
# Out:
# 연도
# 2021    528.333333
# 2018    527.333333
# 2022    524.416667
# 2019    520.500000
# 2020    514.916667
# Name: 총범죄건수, dtype: float64

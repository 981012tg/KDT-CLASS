# %%
#if문은 왜 필요할까?
##돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어가라 --> 이걸 if문으로 만들면?

money = True
if money == True:
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
#if문의 구조
#if 조건문:           <--여기서 '조건문' 자리는 True, False로 나타낼 수 있어야함, :반드시 필요
#    수행할 문장1      --> 4칸이 자동으로 띄워짐
#    수행할 문장2
#else:
#    수행할 문장3
#    수행할 문장4

# %%
# 들여쓰기 방법
money = True

if money:
    print("택시를")
    print("타고")  #띄워쓰기 맞춰야한다
    print("가라")
# Out:
#   Cell In[11], line 7
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
money = True

if money:
    print("택시를")
    print("타고")
        print("가라")  #띄워쓰기 맞춰야한다
# Out:
#   Cell In[10], line 6
#     print("가라")  #띄워쓰기 맞춰야한다
#     ^
# IndentationError: unexpected indent

# %%
#"만약에 3000원 이상의 돈을 가지고 있으면 택시를 타고 가고 그렇지 않으면 걸어가라"

money = 3000

if money >=3000:
    print("taxi")
else:
    print("walk")
# Out:
# taxi

# %%
#돈이 3000원 이상 있거나, 카드가 있다면 택시를 타고 그렇지 않으면 걸어가라

money = 2000
card = True

if (money >=3000) or (card==True):  #여기서 ()는 안해도 됨
    print("taxi")
else:
    print("walk")
# Out:
# taxi

# %%
#우유 하나를 사오는데 달걀이 있으면 6개 사와라

egg=True

if egg==True:
    print("milk6")
else:
    print("milk1")
# Out:
# milk6

# %%
#다양한 조건을 판단하는 elif

##주머니에 돈이 있으면 택시를 타고 가고
##주머니에 돈은 없지만 카드가 있으면 택시를 타고가고
##돈도 없고 카드도 없으면 걸어가라

pocket=["paper", "phone"]
card=False

if "moeny" in pocket:
    print("taxi1")

elif card==True:
    print("taxi2")

else:
    print("walk")

#if "money" not in pocket and card==False:
#    print("walk")
# Out:
# walk
